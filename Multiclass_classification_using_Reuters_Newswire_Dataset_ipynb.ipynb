# %% [markdown]
# <a href="https://colab.research.google.com/github/kolla-gnana-prasanna/ANN-CIFAR-10--DLT/blob/main/Multiclass_classification_using_Reuters_Newswire_Dataset_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical
def OneHotEncoding_fn(ReutersData, dimension=10000):
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
              OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data
x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)
y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 1s 41ms/step - loss: 2.7276 - categorical_accuracy: 0.5121 - val_loss: 1.8024 - val_categorical_accuracy: 0.6438
# Epoch 2/25
# 16/16 [==============================] - 0s 28ms/step - loss: 1.5232 - categorical_accuracy: 0.6935 - val_loss: 1.3427 - val_categorical_accuracy: 0.6975
# Epoch 3/25
# 16/16 [==============================] - 0s 27ms/step - loss: 1.1643 - categorical_accuracy: 0.7466 - val_loss: 1.1668 - val_categorical_accuracy: 0.7437
# Epoch 4/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.9508 - categorical_accuracy: 0.7903 - val_loss: 1.0625 - val_categorical_accuracy: 0.7675
# Epoch 5/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.7878 - categorical_accuracy: 0.8312 - val_loss: 1.0078 - val_categorical_accuracy: 0.7850
# Epoch 6/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.6499 - categorical_accuracy: 0.8636 - val_loss: 0.9502 - val_categorical_accuracy: 0.8012
# Epoch 7/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.5400 - categorical_accuracy: 0.8876 - val_loss: 0.9256 - val_categorical_accuracy: 0.8050
# Epoch 8/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.4507 - categorical_accuracy: 0.9066 - val_loss: 0.9178 - val_categorical_accuracy: 0.8112
# Epoch 9/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.3840 - categorical_accuracy: 0.9181 - val_loss: 0.9093 - val_categorical_accuracy: 0.8075
# Epoch 10/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3286 - categorical_accuracy: 0.9301 - val_loss: 0.8974 - val_categorical_accuracy: 0.8112
# Epoch 11/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2803 - categorical_accuracy: 0.9384 - val_loss: 0.9133 - val_categorical_accuracy: 0.8150
# Epoch 12/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2513 - categorical_accuracy: 0.9429 - val_loss: 0.9370 - val_categorical_accuracy: 0.8075
# Epoch 13/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2179 - categorical_accuracy: 0.9482 - val_loss: 0.9828 - val_categorical_accuracy: 0.7987
# Epoch 14/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1982 - categorical_accuracy: 0.9494 - val_loss: 0.9347 - val_categorical_accuracy: 0.8125
# Epoch 15/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1805 - categorical_accuracy: 0.9525 - val_loss: 0.9825 - val_categorical_accuracy: 0.8100
# Epoch 16/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1696 - categorical_accuracy: 0.9531 - val_loss: 0.9665 - val_categorical_accuracy: 0.8100
# Epoch 17/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1552 - categorical_accuracy: 0.9545 - val_loss: 1.0884 - val_categorical_accuracy: 0.7862
# Epoch 18/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1496 - categorical_accuracy: 0.9572 - val_loss: 0.9900 - val_categorical_accuracy: 0.8100
# Epoch 19/25
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1397 - categorical_accuracy: 0.9553 - val_loss: 1.0214 - val_categorical_accuracy: 0.7962
# Epoch 20/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1340 - categorical_accuracy: 0.9559 - val_loss: 1.0708 - val_categorical_accuracy: 0.8050
# Epoch 21/25
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1263 - categorical_accuracy: 0.9575 - val_loss: 1.0901 - val_categorical_accuracy: 0.8050
# Epoch 22/25
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1239 - categorical_accuracy: 0.9570 - val_loss: 1.0137 - val_categorical_accuracy: 0.8163
# Epoch 23/25
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1260 - categorical_accuracy: 0.9555 - val_loss: 1.0770 - val_categorical_accuracy: 0.8062
# Epoch 24/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1169 - categorical_accuracy: 0.9560 - val_loss: 1.0674 - val_categorical_accuracy: 0.8075
# Epoch 25/25
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1169 - categorical_accuracy: 0.9566 - val_loss: 1.0749 - val_categorical_accuracy: 0.8025

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
